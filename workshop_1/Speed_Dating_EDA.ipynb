# %% [markdown]
# # Speed Dating Data Exploratory Data Analysis

# %%
#First let's import the necessary modules
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import os
from IPython.display import display, HTML

pd.set_option('display.max_columns', 50)

# %%
#Specifying the Data Path

cwd = os.getcwd()
file_path = os.path.join(cwd, 'cleaned_speed_dating.csv')

# %% [markdown]
# Here, we explore some basic dataset details.

# %%
#Reading the CSV, as easy as this! df stands for dataframe
df=pd.read_csv(file_path)

# %%
df.head()
# Out:
#    iid  gender   age  date  sports  tvsports  exercise  dining  museums  art  \
# 0    1       0  21.0   7.0     9.0       2.0       8.0     9.0      1.0  1.0
# 1    1       0  21.0   7.0     9.0       2.0       8.0     9.0      1.0  1.0
# 2    1       0  21.0   7.0     9.0       2.0       8.0     9.0      1.0  1.0
# 3    1       0  21.0   7.0     9.0       2.0       8.0     9.0      1.0  1.0
# 4    1       0  21.0   7.0     9.0       2.0       8.0     9.0      1.0  1.0
#
#    hiking  gaming  clubbing  reading   tv  theater  movies  concerts  music  \
# 0     5.0     1.0       5.0      6.0  9.0      1.0    10.0      10.0    9.0
# 1     5.0     1.0       5.0      6.0  9.0      1.0    10.0      10.0    9.0
# 2     5.0     1.0       5.0      6.0  9.0      1.0    10.0      10.0    9.0
# 3     5.0     1.0       5.0      6.0  9.0      1.0    10.0      10.0    9.0
# 4     5.0     1.0       5.0      6.0  9.0      1.0    10.0      10.0    9.0
#
#    shopping  yoga  attr_want  sinc_want  intel_want  fun_want  amb_want  \
# 0       8.0   1.0       15.0       20.0        20.0      15.0      15.0
# 1       8.0   1.0       15.0       20.0        20.0      15.0      15.0
# 2       8.0   1.0       15.0       20.0        20.0      15.0      15.0
# 3       8.0   1.0       15.0       20.0        20.0      15.0      15.0
# 4       8.0   1.0       15.0       20.0        20.0      15.0      15.0
#
#    shar_want  attr_self  sinc_self  fun_self  intel_self  amb_self   pid  \
# 0       15.0        6.0        8.0       8.0         8.0       7.0  11.0
# 1       15.0        6.0        8.0       8.0         8.0       7.0  12.0
# 2       15.0        6.0        8.0       8.0         8.0       7.0  14.0
# 3       15.0        6.0        8.0       8.0         8.0       7.0  15.0
# 4       15.0        6.0        8.0       8.0         8.0       7.0  16.0
#
#    age_partner  int_corr  samerace  attr_partner  sinc_partner  intel_partner  \
# 0         27.0      0.14         0           6.0           9.0            7.0
# 1         22.0      0.54         0           7.0           8.0            7.0
# 2         23.0      0.61         0           7.0           6.0            8.0
# 3         24.0      0.21         0           5.0           6.0            7.0
# 4         25.0      0.25         0           4.0           9.0            7.0
#
#    fun_partner  amb_partner  shar_partner  prob  dec
# 0          7.0          6.0           5.0   6.0    1
# 1          8.0          5.0           6.0   5.0    1
# 2          7.0          6.0           8.0   6.0    1
# 3          7.0          6.0           6.0   6.0    1
# 4          4.0          6.0           4.0   5.0    0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6712 entries, 0 to 6711
# Data columns (total 44 columns):
# iid              6712 non-null int64
# gender           6712 non-null int64
# age              6712 non-null float64
# date             6712 non-null float64
# sports           6712 non-null float64
# tvsports         6712 non-null float64
# exercise         6712 non-null float64
# dining           6712 non-null float64
# museums          6712 non-null float64
# art              6712 non-null float64
# hiking           6712 non-null float64
# gaming           6712 non-null float64
# clubbing         6712 non-null float64
# reading          6712 non-null float64
# tv               6712 non-null float64
# theater          6712 non-null float64
# movies           6712 non-null float64
# concerts         6712 non-null float64
# music            6712 non-null float64
# shopping         6712 non-null float64
# yoga             6712 non-null float64
# attr_want        6712 non-null float64
# sinc_want        6712 non-null float64
# intel_want       6712 non-null float64
# fun_want         6712 non-null float64
# amb_want         6712 non-null float64
# shar_want        6712 non-null float64
# attr_self        6712 non-null float64
# sinc_self        6712 non-null float64
# fun_self         6712 non-null float64
# intel_self       6712 non-null float64
# amb_self         6712 non-null float64
# pid              6712 non-null float64
# age_partner      6712 non-null float64
# int_corr         6712 non-null float64
# samerace         6712 non-null int64
# attr_partner     6712 non-null float64
# sinc_partner     6712 non-null float64
# intel_partner    6712 non-null float64
# fun_partner      6712 non-null float64
# amb_partner      6712 non-null float64
# shar_partner     6712 non-null float64
# prob             6712 non-null float64
# dec              6712 non-null int64
# dtypes: float64(40), int64(4)
# memory usage: 2.3 MB

# %%
display(df.describe())
# Out:
#                iid       gender          age         date       sports  \
# count  6712.000000  6712.000000  6712.000000  6712.000000  6712.000000
# mean    283.041716     0.509088    26.234505     4.993296     6.452771
# std     158.623235     0.499955     3.472971     1.418774     2.583173
# min       1.000000     0.000000    18.000000     1.000000     1.000000
# 25%     157.000000     0.000000    24.000000     4.000000     5.000000
# 50%     276.000000     1.000000    26.000000     5.000000     7.000000
# 75%     410.000000     1.000000    28.000000     6.000000     8.000000
# max     552.000000     1.000000    55.000000     7.000000    10.000000
#
#           tvsports     exercise       dining      museums          art  \
# count  6712.000000  6712.000000  6712.000000  6712.000000  6712.000000
# mean      4.582837     6.255513     7.843564     7.045888     6.765346
# std       2.800152     2.425919     1.697761     2.024800     2.229007
# min       1.000000     1.000000     1.000000     1.000000     1.000000
# 25%       2.000000     5.000000     7.000000     6.000000     5.000000
# 50%       4.000000     7.000000     8.000000     7.000000     7.000000
# 75%       7.000000     8.000000     9.000000     9.000000     8.000000
# max      10.000000    10.000000    10.000000    10.000000    10.000000
#
#             hiking       gaming     clubbing      reading           tv  \
# count  6712.000000  6712.000000  6712.000000  6712.000000  6712.000000
# mean      5.639154     3.899285     5.781585     7.712753     5.341180
# std       2.573261     2.606684     2.501730     2.015149     2.526884
# min       0.000000     0.000000     1.000000     1.000000     1.000000
# 25%       3.000000     2.000000     4.000000     7.000000     3.000000
# 50%       6.000000     3.000000     6.000000     8.000000     6.000000
# 75%       8.000000     6.000000     8.000000     9.000000     7.000000
# max      10.000000    14.000000    10.000000    13.000000    10.000000
#
#            theater       movies     concerts        music     shopping  \
# count  6712.000000  6712.000000  6712.000000  6712.000000  6712.000000
# mean      6.790524     7.927145     6.835518     7.868892     5.714243
# std       2.233617     1.690180     2.147879     1.763325     2.617694
# min       1.000000     2.000000     1.000000     1.000000     1.000000
# 25%       5.000000     7.000000     5.000000     7.000000     4.000000
# 50%       7.000000     8.000000     7.000000     8.000000     6.000000
# 75%       9.000000     9.000000     9.000000     9.000000     8.000000
# max      10.000000    10.000000    10.000000    10.000000    10.000000
#
#               yoga    attr_want    sinc_want   intel_want     fun_want  \
# count  6712.000000  6712.000000  6712.000000  6712.000000  6712.000000
# mean      4.348629    22.156365    17.471086    20.362278    17.424467
# std       2.732995    11.768449     7.003536     6.642448     6.052239
# min       1.000000     0.000000     0.000000     0.000000     0.000000
# 25%       2.000000    15.000000    15.000000    17.310000    15.000000
# 50%       4.000000    20.000000    18.000000    20.000000    18.000000
# 75%       7.000000    25.000000    20.000000    23.810000    20.000000
# max      10.000000   100.000000    47.000000    50.000000    50.000000
#
#           amb_want    shar_want    attr_self    sinc_self     fun_self  \
# count  6712.000000  6712.000000  6712.000000  6712.000000  6712.000000
# mean     10.846888    11.768305     7.103844     8.311532     7.734356
# std       6.070008     6.225640     1.405050     1.441120     1.566552
# min       0.000000     0.000000     2.000000     2.000000     2.000000
# 25%       5.000000    10.000000     6.000000     8.000000     7.000000
# 50%      10.000000    10.000000     7.000000     9.000000     8.000000
# 75%      15.000000    15.520000     8.000000     9.000000     9.000000
# max      53.000000    30.000000    10.000000    10.000000    10.000000
#
#         intel_self     amb_self          pid  age_partner     int_corr  \
# count  6712.000000  6712.000000  6712.000000  6712.000000  6712.000000
# mean      8.448749     7.633641   282.608164    26.310489     0.197692
# std       1.086236     1.819615   158.209424     3.538261     0.303991
# min       3.000000     2.000000     1.000000    18.000000    -0.830000
# 25%       8.000000     7.000000   155.000000    24.000000    -0.020000
# 50%       8.000000     8.000000   279.000000    26.000000     0.210000
# 75%       9.000000     9.000000   410.000000    28.000000     0.430000
# max      10.000000    10.000000   552.000000    55.000000     0.910000
#
#           samerace  attr_partner  sinc_partner  intel_partner  fun_partner  \
# count  6712.000000   6712.000000   6712.000000    6712.000000  6712.000000
# mean      0.396007      6.190614      7.174091       7.371797     6.406213
# std       0.489102      1.932422      1.727542       1.535912     1.943901
# min       0.000000      0.000000      0.000000       0.000000     0.000000
# 25%       0.000000      5.000000      6.000000       6.000000     5.000000
# 50%       0.000000      6.000000      7.000000       7.000000     7.000000
# 75%       1.000000      8.000000      8.000000       8.000000     8.000000
# max       1.000000     10.000000     10.000000      10.000000    10.000000
#
#        amb_partner  shar_partner         prob          dec
# count  6712.000000   6712.000000  6712.000000  6712.000000
# mean      6.770113      5.472810     5.266687     0.432807
# std       1.778541      2.134391     2.131276     0.495501
# min       0.000000      0.000000     0.000000     0.000000
# 25%       6.000000      4.000000     4.000000     0.000000
# 50%       7.000000      6.000000     5.000000     0.000000
# 75%       8.000000      7.000000     7.000000     1.000000
# max      10.000000     10.000000    10.000000     1.000000

# %% [markdown]
# ### Correlation
#
# We calculate the correlation matrix of the dataframe.

# %%
corr = df.corr()
display(corr)
# Out:
#                     iid    gender       age      date    sports  tvsports  \
# iid            1.000000  0.075595  0.135121  0.025632  0.013925 -0.006568
# gender         0.075595  1.000000  0.101669 -0.110727  0.223592  0.146188
# age            0.135121  0.101669  1.000000  0.026327 -0.062181 -0.136821
# date           0.025632 -0.110727  0.026327  1.000000 -0.117405  0.007285
# sports         0.013925  0.223592 -0.062181 -0.117405  1.000000  0.487856
# tvsports      -0.006568  0.146188 -0.136821  0.007285  0.487856  1.000000
# exercise      -0.000908 -0.095595 -0.033519 -0.102151  0.398752  0.223383
# dining         0.102490 -0.223909  0.026945 -0.117231 -0.079492 -0.038711
# museums        0.051757 -0.226360  0.131839 -0.026865 -0.144879 -0.078332
# art            0.085900 -0.234823  0.091957 -0.022125 -0.141581 -0.089861
# hiking        -0.006684 -0.075168  0.060241  0.027581  0.156282 -0.007514
# gaming         0.018840  0.209828 -0.155174 -0.046236  0.138311  0.278518
# clubbing      -0.041289 -0.071205 -0.101928 -0.083578  0.064810  0.079223
# reading       -0.019751 -0.121646  0.125026  0.023614 -0.156297 -0.150767
# tv             0.000666 -0.189051 -0.183702  0.085137 -0.095122  0.264955
# theater        0.024422 -0.318675  0.008235  0.024478 -0.248350 -0.095239
# movies        -0.010122 -0.160302 -0.033948  0.050502 -0.155172 -0.033279
# concerts       0.070712 -0.126269 -0.074092  0.015090 -0.044290  0.049587
# music          0.075697 -0.073357 -0.040090  0.008106 -0.004631  0.064368
# shopping       0.080154 -0.351544 -0.164909 -0.087941 -0.108101  0.043888
# yoga           0.011717 -0.211486  0.020884 -0.050200 -0.033950 -0.070911
# attr_want      0.110353  0.352193  0.053952 -0.169578  0.190865  0.089286
# concerts          0.060080     0.081669      0.076968  0.067964  0.021536
# music             0.086029     0.096676      0.072515  0.070980 -0.000875
# shopping          0.074690     0.113495      0.095247  0.088059 -0.037207
# yoga              0.011877     0.052526      0.079817  0.076885  0.037107
# attr_want         0.047320    -0.011617      0.040743  0.053756 -0.036302
# sinc_want         0.000174     0.016114      0.002954 -0.041452  0.032512
# intel_want       -0.061707    -0.044087     -0.053595 -0.066984 -0.001733
# fun_want         -0.013361    -0.042747     -0.050648  0.034166  0.012261
# amb_want          0.032631     0.140811      0.031226  0.027503 -0.022152
# shar_want        -0.038813    -0.041269     -0.003628 -0.031934  0.048373
# attr_self         0.049803     0.120584      0.066057  0.267267 -0.043591
# sinc_self         0.059899     0.116691      0.036544  0.067671 -0.024623
# fun_self          0.128729     0.165505      0.111369  0.228172 -0.001594
# intel_self        0.049397     0.085068      0.048614  0.079120  0.048279
# amb_self          0.052990     0.113277      0.055618  0.064792 -0.002103
# pid              -0.003776    -0.027600     -0.048533  0.011376 -0.004303
# age_partner      -0.038596     0.019466      0.003200 -0.003938 -0.047848
# int_corr          0.011683     0.022131      0.038397  0.008866  0.011944
# samerace          0.011721     0.010970      0.057848  0.091078  0.028037
# attr_partner      0.582325     0.344256      0.481296  0.271225  0.486650
# sinc_partner      0.499545     0.451337      0.388421  0.324057  0.201887
# intel_partner     0.491548     0.618017      0.391818  0.271130  0.206550
# fun_partner       1.000000     0.487707      0.611505  0.384694  0.408790
# amb_partner       0.487707     1.000000      0.427940  0.274908  0.178523
# shar_partner      0.611505     0.427940      1.000000  0.469465  0.399857
# prob              0.384694     0.274908      0.469465  1.000000  0.310671
# dec               0.408790     0.178523      0.399857  0.310671  1.000000

# %%
corr_tmp = corr.copy()
display(corr_tmp)
shape = corr_tmp.values.shape
display(corr_tmp.values)
display(shape)

#Setting upper triangular matrix including diagonal (std) to -99, discounting them
bad_indices = np.triu_indices(shape[0])
corr_tmp.values[bad_indices] = -99

arg_corr = np.dstack(np.unravel_index(np.argsort(-corr_tmp.values.ravel()), shape))[0]

arg_corr = arg_corr[:-len(bad_indices[0])]
# Out:
#                     iid    gender       age      date    sports  tvsports  \
# iid            1.000000  0.075595  0.135121  0.025632  0.013925 -0.006568
# gender         0.075595  1.000000  0.101669 -0.110727  0.223592  0.146188
# age            0.135121  0.101669  1.000000  0.026327 -0.062181 -0.136821
# date           0.025632 -0.110727  0.026327  1.000000 -0.117405  0.007285
# sports         0.013925  0.223592 -0.062181 -0.117405  1.000000  0.487856
# tvsports      -0.006568  0.146188 -0.136821  0.007285  0.487856  1.000000
# exercise      -0.000908 -0.095595 -0.033519 -0.102151  0.398752  0.223383
# dining         0.102490 -0.223909  0.026945 -0.117231 -0.079492 -0.038711
# museums        0.051757 -0.226360  0.131839 -0.026865 -0.144879 -0.078332
# art            0.085900 -0.234823  0.091957 -0.022125 -0.141581 -0.089861
# hiking        -0.006684 -0.075168  0.060241  0.027581  0.156282 -0.007514
# gaming         0.018840  0.209828 -0.155174 -0.046236  0.138311  0.278518
#           1.00000000e+00,   4.69465318e-01,   3.99856710e-01],
#        [  1.14906446e-02,   5.20667189e-03,  -6.41714752e-03, ...,
#           4.69465318e-01,   1.00000000e+00,   3.10671331e-01],
#        [  6.65214029e-03,   1.14946341e-01,  -2.80384801e-04, ...,
#           3.99856710e-01,   3.10671331e-01,   1.00000000e+00]])
# (44L, 44L)

# %%
print('Highest Correlation Coefficient\n')

for pair in corr_tmp.columns[arg_corr]:
    print(pair, ' Correlation = ', corr[pair[0]][pair[1]])
    
print('Lowest Correlation Coefficient\n')
# Out:
# Highest Correlation Coefficient
#
# (array(['pid', 'iid'], dtype=object), ' Correlation = ', 0.99301690251307662)
# (array(['art', 'museums'], dtype=object), ' Correlation = ', 0.85362722232884369)
# (array(['intel_partner', 'sinc_partner'], dtype=object), ' Correlation = ', 0.6609918612530532)
# (array(['music', 'concerts'], dtype=object), ' Correlation = ', 0.64704961554359453)
# (array(['amb_partner', 'intel_partner'], dtype=object), ' Correlation = ', 0.61801668058967052)
# (array(['shar_partner', 'fun_partner'], dtype=object), ' Correlation = ', 0.61150467820314103)
# (array(['fun_partner', 'attr_partner'], dtype=object), ' Correlation = ', 0.58232476151703516)
# (array(['theater', 'museums'], dtype=object), ' Correlation = ', 0.55060201204740056)
# (array(['theater', 'art'], dtype=object), ' Correlation = ', 0.53695898216435345)
# (array(['movies', 'theater'], dtype=object), ' Correlation = ', 0.50441407104370029)
# (array(['fun_partner', 'sinc_partner'], dtype=object), ' Correlation = ', 0.49954492864222544)
# (array(['fun_partner', 'intel_partner'], dtype=object), ' Correlation = ', 0.49154831656546677)
# (array(['tvsports', 'sports'], dtype=object), ' Correlation = ', 0.48785610485861108)
# (array(['amb_partner', 'fun_partner'], dtype=object), ' Correlation = ', 0.48770748000002156)
# (array(['dec', 'attr_partner'], dtype=object), ' Correlation = ', 0.48665017581895609)
# (array(['shar_partner', 'attr_partner'], dtype=object), ' Correlation = ', 0.48129613154838763)
# (array(['prob', 'shar_partner'], dtype=object), ' Correlation = ', 0.46946531836803496)
# (array(['amb_partner', 'sinc_partner'], dtype=object), ' Correlation = ', 0.45133673164448779)
# (array(['shopping', 'tv'], dtype=object), ' Correlation = ', 0.43755585211429499)
# (array(['fun_self', 'attr_self'], dtype=object), ' Correlation = ', 0.43341349242563199)
# (array(['shar_partner', 'amb_partner'], dtype=object), ' Correlation = ', 0.42794013947685688)
# (array(['dec', 'fun_partner'], dtype=object), ' Correlation = ', 0.40879040942031541)
# (array(['dec', 'shar_partner'], dtype=object), ' Correlation = ', 0.39985670962131037)
# (array(['exercise', 'sports'], dtype=object), ' Correlation = ', 0.39875218776377547)
# (array(['concerts', 'theater'], dtype=object), ' Correlation = ', 0.39798820202097884)
# (array(['shar_partner', 'intel_partner'], dtype=object), ' Correlation = ', 0.3918184134371604)
# (array(['concerts', 'art'], dtype=object), ' Correlation = ', 0.39172138031365944)
# (array(['sinc_partner', 'attr_partner'], dtype=object), ' Correlation = ', 0.38863910589437251)
# (array(['shar_partner', 'sinc_partner'], dtype=object), ' Correlation = ', 0.38842065647460633)
# (array(['intel_self', 'attr_self'], dtype=object), ' Correlation = ', 0.38821064374337538)
# (array(['shopping', 'dining'], dtype=object), ' Correlation = ', 0.38578026371543839)
# (array(['prob', 'fun_partner'], dtype=object), ' Correlation = ', 0.38469387483382)
# (array(['concerts', 'movies'], dtype=object), ' Correlation = ', 0.37456736997092155)
# (array(['intel_partner', 'attr_partner'], dtype=object), ' Correlation = ', 0.37409889162438037)
# (array(['museums', 'dining'], dtype=object), ' Correlation = ', 0.36819299580074472)
# (array(['concerts', 'museums'], dtype=object), ' Correlation = ', 0.36553646371189119)
# (array(['movies', 'tv'], dtype=object), ' Correlation = ', 0.36026302800706134)
# (array(['attr_want', 'gender'], dtype=object), ' Correlation = ', 0.35219283155676173)
# (array(['amb_self', 'fun_self'], dtype=object), ' Correlation = ', 0.34463324758105901)
# (array(['amb_partner', 'attr_partner'], dtype=object), ' Correlation = ', 0.3442564037025822)
# (array(['amb_self', 'intel_self'], dtype=object), ' Correlation = ', 0.33589431785777785)
# (array(['sinc_self', 'sinc_want'], dtype=object), ' Correlation = ', 0.33015206249171192)
# (array(['amb_self', 'amb_want'], dtype=object), ' Correlation = ', 0.33009972524714093)
# (array(['prob', 'sinc_partner'], dtype=object), ' Correlation = ', 0.32405673161775417)
# (array(['reading', 'museums'], dtype=object), ' Correlation = ', 0.32368857673428281)
# (array(['art', 'dining'], dtype=object), ' Correlation = ', 0.32227219193709039)
# (array(['dec', 'prob'], dtype=object), ' Correlation = ', 0.31067133100423977)
# (array(['yoga', 'art'], dtype=object), ' Correlation = ', 0.30768886111336208)
# (array(['movies', 'museums'], dtype=object), ' Correlation = ', 0.30519740732150286)
# (array(['music', 'movies'], dtype=object), ' Correlation = ', 0.30502843574826133)
# (array(['amb_self', 'attr_self'], dtype=object), ' Correlation = ', 0.30198441452707758)
# (array(['movies', 'art'], dtype=object), ' Correlation = ', 0.29922083229346697)
# (array(['shopping', 'theater'], dtype=object), ' Correlation = ', 0.296753522338152)
# (array(['theater', 'dining'], dtype=object), ' Correlation = ', 0.29486498647020964)
# (array(['fun_self', 'dining'], dtype=object), ' Correlation = ', 0.28786694504279298)
# (array(['gaming', 'tvsports'], dtype=object), ' Correlation = ', 0.27851756745947975)
# (array(['music', 'art'], dtype=object), ' Correlation = ', 0.27760575121457681)
# (array(['prob', 'amb_partner'], dtype=object), ' Correlation = ', 0.2749084485295693)
# (array(['prob', 'attr_partner'], dtype=object), ' Correlation = ', 0.27122494821026322)
# (array(['prob', 'intel_partner'], dtype=object), ' Correlation = ', 0.27113045141952646)
# (array(['intel_self', 'fun_self'], dtype=object), ' Correlation = ', 0.27103232173029479)
# (array(['prob', 'attr_self'], dtype=object), ' Correlation = ', 0.26726748672743933)
# (array(['tv', 'tvsports'], dtype=object), ' Correlation = ', 0.26495463338136199)
# (array(['yoga', 'museums'], dtype=object), ' Correlation = ', 0.26479225702665021)
# (array(['fun_self', 'shopping'], dtype=object), ' Correlation = ', 0.2636067083484312)
# (array(['attr_self', 'exercise'], dtype=object), ' Correlation = ', 0.26058963025692639)
# (array(['yoga', 'theater'], dtype=object), ' Correlation = ', 0.25516047447593765)
# (array(['music', 'museums'], dtype=object), ' Correlation = ', 0.25092539076486808)
# (array(['shopping', 'movies'], dtype=object), ' Correlation = ', 0.25014386774065478)
# (array(['yoga', 'concerts'], dtype=object), ' Correlation = ', 0.24584351449513375)
# (array(['fun_self', 'music'], dtype=object), ' Correlation = ', 0.24372734276567201)
# (array(['fun_self', 'fun_want'], dtype=object), ' Correlation = ', 0.24181480189310905)
# (array(['yoga', 'hiking'], dtype=object), ' Correlation = ', 0.23655100324279138)
# (array(['reading', 'art'], dtype=object), ' Correlation = ', 0.23313121992519856)
# (array(['intel_self', 'sinc_self'], dtype=object), ' Correlation = ', 0.22880346256121714)
# (array(['prob', 'fun_self'], dtype=object), ' Correlation = ', 0.22817172309552836)
# (array(['theater', 'tv'], dtype=object), ' Correlation = ', 0.22627417467810323)
# (array(['sports', 'gender'], dtype=object), ' Correlation = ', 0.22359178285401649)
# (array(['exercise', 'tvsports'], dtype=object), ' Correlation = ', 0.22338251385517377)
# (array(['movies', 'dining'], dtype=object), ' Correlation = ', 0.21407407729524164)
# (array(['concerts', 'dining'], dtype=object), ' Correlation = ', 0.21306981766414212)
# (array(['music', 'theater'], dtype=object), ' Correlation = ', 0.21234421971852213)
# (array(['amb_want', 'shopping'], dtype=object), ' Correlation = ', 0.21198719081775833)
# (array(['gaming', 'gender'], dtype=object), ' Correlation = ', 0.20982817822859684)
# (array(['intel_want', 'reading'], dtype=object), ' Correlation = ', 0.20949665711979215)
# (array(['tv', 'gaming'], dtype=object), ' Correlation = ', 0.2090681920304174)
# (array(['shopping', 'concerts'], dtype=object), ' Correlation = ', 0.20858730411411625)
# (array(['amb_want', 'theater'], dtype=object), ' Correlation = ', 0.20841043402884285)
# (array(['shopping', 'museums'], dtype=object), ' Correlation = ', 0.20784196107833977)
# (array(['shopping', 'music'], dtype=object), ' Correlation = ', 0.20691306815811919)
# (array(['dec', 'intel_partner'], dtype=object), ' Correlation = ', 0.2065499839588017)
# (array(['fun_self', 'sinc_self'], dtype=object), ' Correlation = ', 0.20233156423966314)
# (array(['dec', 'sinc_partner'], dtype=object), ' Correlation = ', 0.20188739393689495)
# (array(['clubbing', 'dining'], dtype=object), ' Correlation = ', 0.2011537155589232)
# (array(['clubbing', 'gaming'], dtype=object), ' Correlation = ', 0.20021871998401494)
# (array(['yoga', 'shopping'], dtype=object), ' Correlation = ', 0.20015371976253707)
# (array(['theater', 'reading'], dtype=object), ' Correlation = ', 0.19926490025788499)
# (array(['amb_self', 'shopping'], dtype=object), ' Correlation = ', 0.19731471045545448)
# (array(['shopping', 'art'], dtype=object), ' Correlation = ', 0.19714965853376709)
# (array(['amb_self', 'dining'], dtype=object), ' Correlation = ', 0.19690825053772704)
# (array(['fun_self', 'clubbing'], dtype=object), ' Correlation = ', 0.19107889477080442)
# (array(['attr_want', 'sports'], dtype=object), ' Correlation = ', 0.19086526426584799)
# (array(['attr_self', 'attr_want'], dtype=object), ' Correlation = ', 0.18936840679735861)
# (array(['hiking', 'art'], dtype=object), ' Correlation = ', 0.18885655316232927)
# (array(['attr_self', 'dining'], dtype=object), ' Correlation = ', 0.18084162311745611)
# (array(['dec', 'amb_partner'], dtype=object), ' Correlation = ', 0.17852306663873127)
# (array(['sinc_want', 'date'], dtype=object), ' Correlation = ', 0.17636697403093557)
# (array(['yoga', 'dining'], dtype=object), ' Correlation = ', 0.17537768874248516)
# (array(['hiking', 'museums'], dtype=object), ' Correlation = ', 0.17482807428160621)
# (array(['amb_self', 'sinc_self'], dtype=object), ' Correlation = ', 0.17286226075428979)
# (array(['intel_want', 'museums'], dtype=object), ' Correlation = ', 0.17149697496914809)
# (array(['music', 'dining'], dtype=object), ' Correlation = ', 0.17049311571784539)
# (array(['sinc_self', 'theater'], dtype=object), ' Correlation = ', 0.16984516559451263)
# (array(['concerts', 'hiking'], dtype=object), ' Correlation = ', 0.16692597750432875)
# (array(['attr_self', 'sports'], dtype=object), ' Correlation = ', 0.16620842496400393)
# (array(['gaming', 'hiking'], dtype=object), ' Correlation = ', 0.16554550031376425)
# (array(['amb_partner', 'fun_self'], dtype=object), ' Correlation = ', 0.16550473013887798)
# (array(['int_corr', 'museums'], dtype=object), ' Correlation = ', 0.1642945151643217)
# (array(['int_corr', 'art'], dtype=object), ' Correlation = ', 0.16399094351141083)
# (array(['fun_self', 'tvsports'], dtype=object), ' Correlation = ', 0.16312725800832442)
# (array(['amb_self', 'music'], dtype=object), ' Correlation = ', 0.16196749487769113)
# (array(['sinc_self', 'attr_self'], dtype=object), ' Correlation = ', 0.16144710565530079)
# (array(['attr_self', 'yoga'], dtype=object), ' Correlation = ', 0.15940914895705999)
# (array(['yoga', 'music'], dtype=object), ' Correlation = ', 0.15793370820261857)
# (array(['intel_partner', 'fun_self'], dtype=object), ' Correlation = ', 0.15692545542482303)
# (array(['amb_self', 'exercise'], dtype=object), ' Correlation = ', 0.15657274075265254)
# (array(['hiking', 'sports'], dtype=object), ' Correlation = ', 0.15628192787659204)
# (array(['sinc_self', 'reading'], dtype=object), ' Correlation = ', 0.15550302421485668)
# (array(['shopping', 'clubbing'], dtype=object), ' Correlation = ', 0.15541016292887666)
# (array(['attr_self', 'shopping'], dtype=object), ' Correlation = ', 0.15517457672614188)
# (array(['amb_self', 'sports'], dtype=object), ' Correlation = ', 0.15278104802926476)
# (array(['int_corr', 'reading'], dtype=object), ' Correlation = ', 0.15203851251854253)
# (array(['fun_self', 'sports'], dtype=object), ' Correlation = ', 0.14914230977785173)
# (array(['amb_want', 'dining'], dtype=object), ' Correlation = ', 0.14746090687343968)
# (array(['tvsports', 'gender'], dtype=object), ' Correlation = ', 0.1461882549310336)
# (array(['intel_self', 'dining'], dtype=object), ' Correlation = ', 0.14448559417172563)
# (array(['fun_self', 'yoga'], dtype=object), ' Correlation = ', 0.14397046757818213)
# (array(['intel_self', 'sports'], dtype=object), ' Correlation = ', 0.14132574909238305)
# (array(['fun_self', 'art'], dtype=object), ' Correlation = ', 0.14131750460848538)
# (array(['amb_partner', 'amb_want'], dtype=object), ' Correlation = ', 0.14081107867746998)
# (array(['gaming', 'sports'], dtype=object), ' Correlation = ', 0.13831078780996453)
# (array(['sinc_self', 'concerts'], dtype=object), ' Correlation = ', 0.13709836386658636)
# (array(['fun_self', 'concerts'], dtype=object), ' Correlation = ', 0.13563349016134485)
# (array(['sinc_partner', 'fun_self'], dtype=object), ' Correlation = ', 0.13527814902648658)
# (array(['intel_self', 'reading'], dtype=object), ' Correlation = ', 0.13520775155931139)
# (array(['age', 'iid'], dtype=object), ' Correlation = ', 0.13512112460523748)
# (array(['amb_self', 'yoga'], dtype=object), ' Correlation = ', 0.13244759314026039)
# (array(['museums', 'age'], dtype=object), ' Correlation = ', 0.13183890544465718)
# (array(['movies', 'reading'], dtype=object), ' Correlation = ', 0.13096559634047816)
# (array(['fun_partner', 'fun_self'], dtype=object), ' Correlation = ', 0.12872944501795716)
# (array(['reading', 'age'], dtype=object), ' Correlation = ', 0.12502589887285298)
# (array(['pid', 'dining'], dtype=object), ' Correlation = ', 0.12358048900852514)
# (array(['amb_self', 'gaming'], dtype=object), ' Correlation = ', 0.12325395061008812)
# (array(['intel_partner', 'intel_self'], dtype=object), ' Correlation = ', 0.12308862462842579)
# (array(['intel_partner', 'attr_self'], dtype=object), ' Correlation = ', 0.12244777771558617)
# (array(['pid', 'age'], dtype=object), ' Correlation = ', 0.12143035813926248)
# (array(['amb_partner', 'attr_self'], dtype=object), ' Correlation = ', 0.12058352995766086)
# (array(['sinc_self', 'hiking'], dtype=object), ' Correlation = ', 0.12028523988004058)
# (array(['attr_self', 'music'], dtype=object), ' Correlation = ', 0.119588251811197)
# (array(['attr_self', 'clubbing'], dtype=object), ' Correlation = ', 0.11925777995409512)
# (array(['shar_want', 'amb_want'], dtype=object), ' Correlation = ', 0.11921968856196052)
# (array(['attr_partner', 'gender'], dtype=object), ' Correlation = ', 0.11884849286710196)
# (array(['sinc_self', 'movies'], dtype=object), ' Correlation = ', 0.11845706191838594)
# (array(['pid', 'shopping'], dtype=object), ' Correlation = ', 0.11838995648637013)
# (array(['intel_partner', 'tv'], dtype=object), ' Correlation = ', 0.11810256952642294)
# (array(['prob', 'sports'], dtype=object), ' Correlation = ', 0.11788582555289397)
# (array(['amb_partner', 'sinc_self'], dtype=object), ' Correlation = ', 0.11669115276461905)
# (array(['intel_partner', 'sinc_self'], dtype=object), ' Correlation = ', 0.11667100739415964)
# (array(['int_corr', 'movies'], dtype=object), ' Correlation = ', 0.11613087661855585)
# (array(['concerts', 'gaming'], dtype=object), ' Correlation = ', 0.11507507277730286)
# (array(['sinc_self', 'museums'], dtype=object), ' Correlation = ', 0.1150537771694938)
# (array(['intel_partner', 'reading'], dtype=object), ' Correlation = ', 0.11503084294458327)
# (array(['dec', 'gender'], dtype=object), ' Correlation = ', 0.11494634141088249)
# (array(['fun_self', 'amb_want'], dtype=object), ' Correlation = ', 0.11432355163062795)
# (array(['prob', 'exercise'], dtype=object), ' Correlation = ', 0.11411733070131003)
# (array(['amb_partner', 'shopping'], dtype=object), ' Correlation = ', 0.11349541032378743)
# (array(['sinc_self', 'tv'], dtype=object), ' Correlation = ', 0.11341138437311399)
# (array(['amb_partner', 'amb_self'], dtype=object), ' Correlation = ', 0.11327686303967054)
# (array(['yoga', 'exercise'], dtype=object), ' Correlation = ', 0.11273632846892591)
# (array(['yoga', 'movies'], dtype=object), ' Correlation = ', 0.11217745010189488)
# (array(['sinc_partner', 'tv'], dtype=object), ' Correlation = ', 0.11180313029494202)
# (array(['shopping', 'gaming'], dtype=object), ' Correlation = ', 0.11176125274454532)
# (array(['fun_self', 'exercise'], dtype=object), ' Correlation = ', 0.11165225225043825)
# (array(['shar_partner', 'fun_self'], dtype=object), ' Correlation = ', 0.11136888976216987)
# (array(['pid', 'art'], dtype=object), ' Correlation = ', 0.11100486882021689)
# (array(['amb_partner', 'tv'], dtype=object), ' Correlation = ', 0.1108223384539764)
# (array(['intel_partner', 'theater'], dtype=object), ' Correlation = ', 0.11072594590210108)
# (array(['shopping', 'exercise'], dtype=object), ' Correlation = ', 0.11059151237600955)
# (array(['attr_want', 'iid'], dtype=object), ' Correlation = ', 0.11035298792926734)
# (array(['intel_want', 'art'], dtype=object), ' Correlation = ', 0.11035287796015102)
# (array(['attr_want', 'exercise'], dtype=object), ' Correlation = ', 0.10993069666581315)
# (array(['age_partner', 'age'], dtype=object), ' Correlation = ', 0.10796237028744526)
# (array(['sinc_self', 'music'], dtype=object), ' Correlation = ', 0.10749235481995166)
# (array(['amb_want', 'clubbing'], dtype=object), ' Correlation = ', 0.10740473655996699)
# (array(['intel_self', 'exercise'], dtype=object), ' Correlation = ', 0.10706652472367563)
# (array(['clubbing', 'art'], dtype=object), ' Correlation = ', 0.10688594376869112)
# (array(['sinc_partner', 'sinc_self'], dtype=object), ' Correlation = ', 0.10548894232847106)
# (array(['int_corr', 'theater'], dtype=object), ' Correlation = ', 0.10506482208406319)
# (array(['amb_want', 'art'], dtype=object), ' Correlation = ', 0.10437216771708374)
# (array(['amb_want', 'tv'], dtype=object), ' Correlation = ', 0.10327612780740777)
# (array(['amb_self', 'clubbing'], dtype=object), ' Correlation = ', 0.10258418864098276)
# (array(['dining', 'iid'], dtype=object), ' Correlation = ', 0.10248969377108622)
# (array(['age', 'gender'], dtype=object), ' Correlation = ', 0.10166879568966482)
# (array(['amb_partner', 'reading'], dtype=object), ' Correlation = ', 0.10151917706727122)
# (array(['sinc_self', 'date'], dtype=object), ' Correlation = ', 0.10130249879198815)
# (array(['age_partner', 'pid'], dtype=object), ' Correlation = ', 0.099957698860037122)
# (array(['fun_self', 'gaming'], dtype=object), ' Correlation = ', 0.099452079779956723)
# (array(['concerts', 'clubbing'], dtype=object), ' Correlation = ', 0.099050874500534014)
# (array(['sinc_want', 'movies'], dtype=object), ' Correlation = ', 0.098689085402898988)
# (array(['sinc_partner', 'intel_self'], dtype=object), ' Correlation = ', 0.098475819257792807)
# (array(['intel_want', 'theater'], dtype=object), ' Correlation = ', 0.098204498898265588)
# (array(['theater', 'clubbing'], dtype=object), ' Correlation = ', 0.098156436130443878)
# (array(['amb_want', 'yoga'], dtype=object), ' Correlation = ', 0.097916337427274791)
# (array(['intel_self', 'intel_want'], dtype=object), ' Correlation = ', 0.097473703890379654)
# (array(['attr_self', 'art'], dtype=object), ' Correlation = ', 0.097228980673882401)
# (array(['amb_partner', 'music'], dtype=object), ' Correlation = ', 0.096675573235670803)
# (array(['sinc_want', 'tv'], dtype=object), ' Correlation = ', 0.096464740090308865)
# (array(['dec', 'gaming'], dtype=object), ' Correlation = ', 0.096166854876856819)
# (array(['music', 'tv'], dtype=object), ' Correlation = ', 0.095518919228009341)
# (array(['shar_partner', 'shopping'], dtype=object), ' Correlation = ', 0.095247236735366739)
# (array(['amb_want', 'museums'], dtype=object), ' Correlation = ', 0.095222690154810663)
# (array(['amb_partner', 'movies'], dtype=object), ' Correlation = ', 0.095153191268179449)
# (array(['intel_partner', 'amb_self'], dtype=object), ' Correlation = ', 0.09505100267057269)
# (array(['dining', 'exercise'], dtype=object), ' Correlation = ', 0.094727757410965063)
# (array(['concerts', 'tv'], dtype=object), ' Correlation = ', 0.09465475843837054)
# (array(['amb_want', 'movies'], dtype=object), ' Correlation = ', 0.094252947378209218)
# (array(['intel_partner', 'amb_want'], dtype=object), ' Correlation = ', 0.094189656812915773)
# (array(['tv', 'dining'], dtype=object), ' Correlation = ', 0.093580835816815144)
# (array(['amb_self', 'tvsports'], dtype=object), ' Correlation = ', 0.093268011083144531)
# (array(['sinc_want', 'theater'], dtype=object), ' Correlation = ', 0.09277373622507136)
# (array(['reading', 'dining'], dtype=object), ' Correlation = ', 0.092264615234280395)
# (array(['amb_self', 'theater'], dtype=object), ' Correlation = ', 0.09212968592308271)
# (array(['sinc_partner', 'attr_self'], dtype=object), ' Correlation = ', 0.092001523995552698)
# (array(['art', 'age'], dtype=object), ' Correlation = ', 0.09195744778484076)
# (array(['shar_partner', 'gaming'], dtype=object), ' Correlation = ', 0.091800079703908258)
# (array(['shar_want', 'date'], dtype=object), ' Correlation = ', 0.091698077123534574)
# (array(['prob', 'samerace'], dtype=object), ' Correlation = ', 0.091077907235169092)
# (array(['fun_self', 'theater'], dtype=object), ' Correlation = ', 0.090813295863579904)
# (array(['sinc_self', 'dining'], dtype=object), ' Correlation = ', 0.090690583678578851)
# (array(['attr_self', 'museums'], dtype=object), ' Correlation = ', 0.090507930308933005)
# (array(['age_partner', 'iid'], dtype=object), ' Correlation = ', 0.090189422613834613)
# (array(['attr_want', 'tvsports'], dtype=object), ' Correlation = ', 0.089285515591074352)
# (array(['clubbing', 'museums'], dtype=object), ' Correlation = ', 0.08881624730452857)
# (array(['int_corr', 'age_partner'], dtype=object), ' Correlation = ', 0.088115755890437464)
# (array(['prob', 'shopping'], dtype=object), ' Correlation = ', 0.088059009157511969)
# (array(['amb_self', 'art'], dtype=object), ' Correlation = ', 0.087988210337447512)
# (array(['intel_partner', 'music'], dtype=object), ' Correlation = ', 0.087793008272251061)
# (array(['sinc_self', 'tvsports'], dtype=object), ' Correlation = ', 0.086306463701405531)
# (array(['prob', 'dining'], dtype=object), ' Correlation = ', 0.086172005789183534)
# (array(['fun_partner', 'music'], dtype=object), ' Correlation = ', 0.086028951957094757)
# (array(['intel_want', 'movies'], dtype=object), ' Correlation = ', 0.085938863071036556)
# (array(['art', 'iid'], dtype=object), ' Correlation = ', 0.085899637047969102)
# (array(['intel_partner', 'museums'], dtype=object), ' Correlation = ', 0.085717833247473826)
# (array(['amb_partner', 'theater'], dtype=object), ' Correlation = ', 0.085663212134589717)
# (array(['attr_self', 'amb_want'], dtype=object), ' Correlation = ', 0.085377760679235248)
# (array(['tv', 'date'], dtype=object), ' Correlation = ', 0.085137152858508619)
# (array(['amb_partner', 'intel_self'], dtype=object), ' Correlation = ', 0.085068400250400467)
# (array(['int_corr', 'music'], dtype=object), ' Correlation = ', 0.085032324928207892)
# (array(['fun_self', 'museums'], dtype=object), ' Correlation = ', 0.08408040373176319)
# (array(['music', 'gaming'], dtype=object), ' Correlation = ', 0.083813638421685072)
# (array(['sinc_self', 'yoga'], dtype=object), ' Correlation = ', 0.083385115516145636)
# (array(['attr_partner', 'gaming'], dtype=object), ' Correlation = ', 0.083297625400648764)
# (array(['sinc_self', 'art'], dtype=object), ' Correlation = ', 0.082925213470416273)
# (array(['gaming', 'dining'], dtype=object), ' Correlation = ', 0.082803797220053099)
# (array(['pid', 'concerts'], dtype=object), ' Correlation = ', 0.082762874154944113)
# (array(['int_corr', 'age'], dtype=object), ' Correlation = ', 0.082612659943790634)
# (array(['age_partner', 'amb_want'], dtype=object), ' Correlation = ', 0.082434611117356657)
# (array(['fun_self', 'attr_want'], dtype=object), ' Correlation = ', 0.081908466865684426)
# (array(['int_corr', 'intel_want'], dtype=object), ' Correlation = ', 0.081864392914319253)
# (array(['amb_partner', 'concerts'], dtype=object), ' Correlation = ', 0.081668517318718131)
# (array(['attr_want', 'gaming'], dtype=object), ' Correlation = ', 0.081407358526046705)
# (array(['pid', 'music'], dtype=object), ' Correlation = ', 0.080750050209467336)
# (array(['shopping', 'iid'], dtype=object), ' Correlation = ', 0.08015392471405243)
# (array(['concerts', 'reading'], dtype=object), ' Correlation = ', 0.07990032678604661)
# (array(['shar_partner', 'yoga'], dtype=object), ' Correlation = ', 0.079817466414511484)
# (array(['intel_self', 'tvsports'], dtype=object), ' Correlation = ', 0.079632947718314973)
# (array(['pid', 'sinc_self'], dtype=object), ' Correlation = ', 0.079579334713773431)
# (array(['clubbing', 'tvsports'], dtype=object), ' Correlation = ', 0.079223069221790385)
# (array(['shar_want', 'tv'], dtype=object), ' Correlation = ', 0.079205587129213148)
# (array(['prob', 'intel_self'], dtype=object), ' Correlation = ', 0.079119860467324651)
# (array(['sinc_want', 'hiking'], dtype=object), ' Correlation = ', 0.077502757379933243)
# (array(['intel_partner', 'shopping'], dtype=object), ' Correlation = ', 0.07716677728227439)
# (array(['pid', 'museums'], dtype=object), ' Correlation = ', 0.077151485297310252)
# (array(['movies', 'clubbing'], dtype=object), ' Correlation = ', 0.077147860978781263)
# (array(['hiking', 'dining'], dtype=object), ' Correlation = ', 0.077018973399273008)
# (array(['shar_partner', 'concerts'], dtype=object), ' Correlation = ', 0.076967526455818419)
# (array(['prob', 'yoga'], dtype=object), ' Correlation = ', 0.076885464645519111)
# (array(['intel_self', 'gender'], dtype=object), ' Correlation = ', 0.076724836782966488)
# (array(['intel_partner', 'art'], dtype=object), ' Correlation = ', 0.076541497937459457)
# (array(['theater', 'hiking'], dtype=object), ' Correlation = ', 0.075718122238722138)
# (array(['music', 'iid'], dtype=object), ' Correlation = ', 0.075696553396643981)
# (array(['gender', 'iid'], dtype=object), ' Correlation = ', 0.075594794406765142)
# (array(['attr_self', 'tvsports'], dtype=object), ' Correlation = ', 0.075094865503524247)
# (array(['music', 'clubbing'], dtype=object), ' Correlation = ', 0.074981270515812354)
# (array(['intel_self', 'gaming'], dtype=object), ' Correlation = ', 0.074747503290643114)
# (array(['fun_partner', 'shopping'], dtype=object), ' Correlation = ', 0.074690400823605105)
# (array(['amb_self', 'tv'], dtype=object), ' Correlation = ', 0.074633619221669112)
# (array(['prob', 'clubbing'], dtype=object), ' Correlation = ', 0.074603035158906678)
# (array(['sinc_partner', 'reading'], dtype=object), ' Correlation = ', 0.073328336317098827)
# (array(['pid', 'attr_want'], dtype=object), ' Correlation = ', 0.072576083631318081)
# (array(['shar_partner', 'music'], dtype=object), ' Correlation = ', 0.072515449098385837)
# (array(['attr_self', 'hiking'], dtype=object), ' Correlation = ', 0.072391545588451622)
# (array(['fun_partner', 'tv'], dtype=object), ' Correlation = ', 0.072070591653075389)
# (array(['shar_want', 'concerts'], dtype=object), ' Correlation = ', 0.071843700852550693)
# (array(['fun_partner', 'gaming'], dtype=object), ' Correlation = ', 0.071638286230352691)
# (array(['sinc_self', 'iid'], dtype=object), ' Correlation = ', 0.071336699872595971)
# (array(['amb_partner', 'museums'], dtype=object), ' Correlation = ', 0.071244399688272772)
# (array(['pid', 'amb_self'], dtype=object), ' Correlation = ', 0.071158375787813491)
# (array(['prob', 'music'], dtype=object), ' Correlation = ', 0.070980369756633008)
# (array(['intel_partner', 'movies'], dtype=object), ' Correlation = ', 0.070849543313736191)
# (array(['concerts', 'iid'], dtype=object), ' Correlation = ', 0.070712361833158807)
# (array(['hiking', 'exercise'], dtype=object), ' Correlation = ', 0.070460730138314207)
# (array(['fun_self', 'tv'], dtype=object), ' Correlation = ', 0.069915001248089761)
# (array(['sinc_partner', 'music'], dtype=object), ' Correlation = ', 0.069739657805853283)
# (array(['sinc_partner', 'amb_self'], dtype=object), ' Correlation = ', 0.069733868650061842)
# (array(['amb_self', 'iid'], dtype=object), ' Correlation = ', 0.068432291039689702)
# (array(['attr_partner', 'intel_self'], dtype=object), ' Correlation = ', 0.068203465264955618)
# (array(['prob', 'concerts'], dtype=object), ' Correlation = ', 0.067963782101456996)
# (array(['prob', 'sinc_self'], dtype=object), ' Correlation = ', 0.067671061680185038)
# (array(['music', 'reading'], dtype=object), ' Correlation = ', 0.067649965958057612)
# (array(['amb_self', 'movies'], dtype=object), ' Correlation = ', 0.067193893999498558)
# (array(['int_corr', 'dining'], dtype=object), ' Correlation = ', 0.066857812777055436)
# (array(['amb_self', 'attr_want'], dtype=object), ' Correlation = ', 0.066626545387340794)
# (array(['intel_want', 'age'], dtype=object), ' Correlation = ', 0.066559389530764665)
# (array(['shar_partner', 'attr_self'], dtype=object), ' Correlation = ', 0.066057121268017119)
# (array(['sinc_want', 'concerts'], dtype=object), ' Correlation = ', 0.065808782436658289)
# (array(['sinc_partner', 'amb_want'], dtype=object), ' Correlation = ', 0.065072702254040465)
# (array(['clubbing', 'sports'], dtype=object), ' Correlation = ', 0.064810168358907183)
# (array(['prob', 'amb_self'], dtype=object), ' Correlation = ', 0.064792339997153128)
# (array(['sinc_partner', 'art'], dtype=object), ' Correlation = ', 0.064746876215008936)
# (array(['music', 'tvsports'], dtype=object), ' Correlation = ', 0.064367768772927672)
# (array(['amb_partner', 'art'], dtype=object), ' Correlation = ', 0.064252255785175641)
# (array(['int_corr', 'concerts'], dtype=object), ' Correlation = ', 0.064023720980531496)
# (array(['sinc_partner', 'tvsports'], dtype=object), ' Correlation = ', 0.063885441091664164)
# (array(['shar_partner', 'dining'], dtype=object), ' Correlation = ', 0.063611936903579316)
# (array(['sinc_partner', 'theater'], dtype=object), ' Correlation = ', 0.06285922341589463)
# (array(['attr_partner', 'fun_self'], dtype=object), ' Correlation = ', 0.062796658531795502)
# (array(['amb_want', 'hiking'], dtype=object), ' Correlation = ', 0.062361854543102661)
# (array(['amb_self', 'reading'], dtype=object), ' Correlation = ', 0.062161440534145046)
# (array(['fun_self', 'movies'], dtype=object), ' Correlation = ', 0.061798374124623398)
# (array(['yoga', 'clubbing'], dtype=object), ' Correlation = ', 0.061656725793154545)
# (array(['amb_want', 'date'], dtype=object), ' Correlation = ', 0.06158881176150946)
# (array(['amb_want', 'exercise'], dtype=object), ' Correlation = ', 0.061067975029114575)
# (array(['hiking', 'age'], dtype=object), ' Correlation = ', 0.060241042530103567)
# (array(['fun_partner', 'concerts'], dtype=object), ' Correlation = ', 0.060080187073142978)
# (array(['sinc_self', 'shar_want'], dtype=object), ' Correlation = ', 0.059951537570235344)
# (array(['fun_partner', 'sinc_self'], dtype=object), ' Correlation = ', 0.059898894891462932)
# (array(['amb_partner', 'dining'], dtype=object), ' Correlation = ', 0.059544605693165595)
# (array(['shar_partner', 'museums'], dtype=object), ' Correlation = ', 0.059299828433267768)
# (array(['sinc_partner', 'shopping'], dtype=object), ' Correlation = ', 0.058830489728866439)
# (array(['prob', 'gaming'], dtype=object), ' Correlation = ', 0.058331074526875991)
# (array(['fun_partner', 'tvsports'], dtype=object), ' Correlation = ', 0.058196772707244319)
# (array(['age_partner', 'art'], dtype=object), ' Correlation = ', 0.05787103952676758)
# (array(['shar_partner', 'samerace'], dtype=object), ' Correlation = ', 0.057847546972486438)
# (array(['yoga', 'reading'], dtype=object), ' Correlation = ', 0.05771514271036067)
# (array(['fun_partner', 'art'], dtype=object), ' Correlation = ', 0.057526402069834406)
# (array(['shar_partner', 'art'], dtype=object), ' Correlation = ', 0.057102603135502354)
# (array(['int_corr', 'pid'], dtype=object), ' Correlation = ', 0.056955614122345635)
# (array(['int_corr', 'iid'], dtype=object), ' Correlation = ', 0.056751702617697221)
# (array(['pid', 'theater'], dtype=object), ' Correlation = ', 0.056150748924770309)
# (array(['shar_partner', 'amb_self'], dtype=object), ' Correlation = ', 0.055618498952468232)
# (array(['amb_self', 'concerts'], dtype=object), ' Correlation = ', 0.055303559196899603)
# (array(['sinc_partner', 'movies'], dtype=object), ' Correlation = ', 0.055096784011052342)
# (array(['age_partner', 'museums'], dtype=object), ' Correlation = ', 0.054896030840095013)
# (array(['fun_partner', 'gender'], dtype=object), ' Correlation = ', 0.054195312229991618)
# (array(['attr_want', 'age'], dtype=object), ' Correlation = ', 0.053951745228615726)
# (array(['intel_partner', 'exercise'], dtype=object), ' Correlation = ', 0.053843579349444004)
# (array(['prob', 'attr_want'], dtype=object), ' Correlation = ', 0.053755756775495239)
# (array(['attr_partner', 'samerace'], dtype=object), ' Correlation = ', 0.053248128041344774)
# (array(['fun_partner', 'amb_self'], dtype=object), ' Correlation = ', 0.052990391278740973)
# (array(['shar_partner', 'exercise'], dtype=object), ' Correlation = ', 0.052567021872189312)
# (array(['amb_partner', 'yoga'], dtype=object), ' Correlation = ', 0.052526416049436253)
# (array(['sinc_partner', 'museums'], dtype=object), ' Correlation = ', 0.052519750707573858)
# (array(['fun_partner', 'museums'], dtype=object), ' Correlation = ', 0.052485656169675432)
# (array(['intel_partner', 'tvsports'], dtype=object), ' Correlation = ', 0.052439198323782979)
# (array(['sinc_self', 'sports'], dtype=object), ' Correlation = ', 0.052246199153358194)
# (array(['music', 'hiking'], dtype=object), ' Correlation = ', 0.051967036413666068)
# (array(['museums', 'iid'], dtype=object), ' Correlation = ', 0.051757448618933645)
# (array(['movies', 'date'], dtype=object), ' Correlation = ', 0.050501979342340832)
# (array(['fun_partner', 'attr_self'], dtype=object), ' Correlation = ', 0.049803010284044644)
# (array(['concerts', 'tvsports'], dtype=object), ' Correlation = ', 0.049586855162285441)
# (array(['amb_self', 'museums'], dtype=object), ' Correlation = ', 0.049456121296418958)
# (array(['fun_partner', 'intel_self'], dtype=object), ' Correlation = ', 0.049397428477114189)
# (array(['shar_partner', 'theater'], dtype=object), ' Correlation = ', 0.04868931965560961)
# (array(['shar_partner', 'intel_self'], dtype=object), ' Correlation = ', 0.048614314618995125)
# (array(['dec', 'shar_want'], dtype=object), ' Correlation = ', 0.048372934566850732)
# (array(['dec', 'intel_self'], dtype=object), ' Correlation = ', 0.048278542549179258)
# (array(['intel_partner', 'concerts'], dtype=object), ' Correlation = ', 0.048215828916339881)
# (array(['fun_want', 'clubbing'], dtype=object), ' Correlation = ', 0.04803283915136141)
# (array(['fun_partner', 'sports'], dtype=object), ' Correlation = ', 0.048014104816259777)
# (array(['intel_self', 'shar_want'], dtype=object), ' Correlation = ', 0.047539505541922128)
# (array(['shar_partner', 'tvsports'], dtype=object), ' Correlation = ', 0.047342588561900767)
# (array(['fun_partner', 'attr_want'], dtype=object), ' Correlation = ', 0.047319880825941164)
# (array(['shar_partner', 'tv'], dtype=object), ' Correlation = ', 0.04730691162193458)
# (array(['intel_want', 'dining'], dtype=object), ' Correlation = ', 0.046959335789022026)
# (array(['amb_self', 'hiking'], dtype=object), ' Correlation = ', 0.046643190738106799)
# (array(['samerace', 'intel_self'], dtype=object), ' Correlation = ', 0.046060841041463338)
# (array(['tv', 'exercise'], dtype=object), ' Correlation = ', 0.045866389181169628)
# (array(['amb_partner', 'exercise'], dtype=object), ' Correlation = ', 0.045441002813653653)
# (array(['samerace', 'exercise'], dtype=object), ' Correlation = ', 0.045065779310791101)
# (array(['reading', 'hiking'], dtype=object), ' Correlation = ', 0.044577372272922362)
# (array(['shopping', 'tvsports'], dtype=object), ' Correlation = ', 0.043887520801428256)
# (array(['intel_partner', 'dining'], dtype=object), ' Correlation = ', 0.043851443110099815)
# (array(['sinc_partner', 'sports'], dtype=object), ' Correlation = ', 0.043823705134031027)
# (array(['amb_want', 'reading'], dtype=object), ' Correlation = ', 0.04330569310559762)
# (array(['fun_want', 'hiking'], dtype=object), ' Correlation = ', 0.042754732100794793)
# (array(['age_partner', 'shar_want'], dtype=object), ' Correlation = ', 0.042580501776736251)
# (array(['shar_partner', 'sports'], dtype=object), ' Correlation = ', 0.042204989388092008)
# (array(['shar_want', 'reading'], dtype=object), ' Correlation = ', 0.042197595844378502)
# (array(['clubbing', 'exercise'], dtype=object), ' Correlation = ', 0.041434376411227603)
# (array(['shar_partner', 'clubbing'], dtype=object), ' Correlation = ', 0.040858357694842085)
# (array(['shar_partner', 'attr_want'], dtype=object), ' Correlation = ', 0.040743046227247753)
# (array(['yoga', 'tv'], dtype=object), ' Correlation = ', 0.04053516337145132)
# (array(['intel_partner', 'int_corr'], dtype=object), ' Correlation = ', 0.040171912836639859)
# (array(['samerace', 'attr_self'], dtype=object), ' Correlation = ', 0.039893212529455734)
# (array(['sinc_self', 'gaming'], dtype=object), ' Correlation = ', 0.039729808664963874)
# (array(['fun_partner', 'reading'], dtype=object), ' Correlation = ', 0.039700689427030658)
# (array(['attr_partner', 'hiking'], dtype=object), ' Correlation = ', 0.039209349300933109)
# (array(['fun_partner', 'theater'], dtype=object), ' Correlation = ', 0.039024909322345154)
# (array(['pid', 'fun_self'], dtype=object), ' Correlation = ', 0.038810372316892362)
# (array(['shar_partner', 'int_corr'], dtype=object), ' Correlation = ', 0.038397135249606112)
# (array(['attr_partner', 'tv'], dtype=object), ' Correlation = ', 0.038172099149412997)
# (array(['amb_partner', 'clubbing'], dtype=object), ' Correlation = ', 0.038160808586422457)
# (array(['pid', 'date'], dtype=object), ' Correlation = ', 0.038089066411839394)
# (array(['attr_partner', 'sinc_self'], dtype=object), ' Correlation = ', 0.037991383999989518)
# (array(['prob', 'art'], dtype=object), ' Correlation = ', 0.037546294787150214)
# (array(['fun_partner', 'clubbing'], dtype=object), ' Correlation = ', 0.037228647669984107)
# (array(['dec', 'yoga'], dtype=object), ' Correlation = ', 0.037107149575801801)
# (array(['sinc_want', 'reading'], dtype=object), ' Correlation = ', 0.036921092622066463)
# (array(['intel_partner', 'age_partner'], dtype=object), ' Correlation = ', 0.03670555500227024)
# (array(['shar_partner', 'sinc_self'], dtype=object), ' Correlation = ', 0.036543839083736443)
# (array(['intel_partner', 'sports'], dtype=object), ' Correlation = ', 0.035908771705547501)
# (array(['prob', 'tvsports'], dtype=object), ' Correlation = ', 0.035872718924055184)
# (array(['prob', 'hiking'], dtype=object), ' Correlation = ', 0.035780542594487999)
# (array(['amb_partner', 'tvsports'], dtype=object), ' Correlation = ', 0.035165953423069073)
# (array(['prob', 'museums'], dtype=object), ' Correlation = ', 0.035025406804077674)
# (array(['age_partner', 'hiking'], dtype=object), ' Correlation = ', 0.03456478136887367)
# (array(['prob', 'fun_want'], dtype=object), ' Correlation = ', 0.034166346413361755)
# (array(['pid', 'yoga'], dtype=object), ' Correlation = ', 0.034017147859099026)
# (array(['clubbing', 'hiking'], dtype=object), ' Correlation = ', 0.033747839422069333)
# (array(['sinc_want', 'music'], dtype=object), ' Correlation = ', 0.033540382952444818)
# (array(['attr_partner', 'reading'], dtype=object), ' Correlation = ', 0.033271699727991579)
# (array(['fun_partner', 'dining'], dtype=object), ' Correlation = ', 0.032915719292580012)
# (array(['intel_self', 'museums'], dtype=object), ' Correlation = ', 0.03291173795091374)
# (array(['sinc_partner', 'gender'], dtype=object), ' Correlation = ', 0.032716099030065907)
# (array(['fun_partner', 'amb_want'], dtype=object), ' Correlation = ', 0.032630603908151846)
# (array(['int_corr', 'shar_want'], dtype=object), ' Correlation = ', 0.032611578354264349)
# (array(['shar_want', 'art'], dtype=object), ' Correlation = ', 0.032601611181519462)
# (array(['shar_want', 'yoga'], dtype=object), ' Correlation = ', 0.032517835513801253)
# (array(['dec', 'sinc_want'], dtype=object), ' Correlation = ', 0.032512223999418555)
# (array(['attr_self', 'age'], dtype=object), ' Correlation = ', 0.032171773538853941)
# (array(['dec', 'clubbing'], dtype=object), ' Correlation = ', 0.032154596025528226)
# (array(['samerace', 'intel_want'], dtype=object), ' Correlation = ', 0.031977102457156792)
# (array(['fun_partner', 'movies'], dtype=object), ' Correlation = ', 0.031889381990539943)
# (array(['sinc_self', 'exercise'], dtype=object), ' Correlation = ', 0.031784398024620034)
# (array(['fun_want', 'sports'], dtype=object), ' Correlation = ', 0.031486252508087828)
# (array(['shar_partner', 'amb_want'], dtype=object), ' Correlation = ', 0.031226361129735467)
# (array(['gaming', 'exercise'], dtype=object), ' Correlation = ', 0.030579557599853431)
# (array(['intel_partner', 'yoga'], dtype=object), ' Correlation = ', 0.03047512720834638)
# (array(['sinc_want', 'age'], dtype=object), ' Correlation = ', 0.030453012690085633)
# (array(['fun_want', 'iid'], dtype=object), ' Correlation = ', 0.030425744571039633)
# (array(['age_partner', 'sinc_want'], dtype=object), ' Correlation = ', 0.030044990020727625)
# (array(['age_partner', 'theater'], dtype=object), ' Correlation = ', 0.029253593198141564)
# (array(['attr_self', 'reading'], dtype=object), ' Correlation = ', 0.029114192804959287)
# (array(['amb_partner', 'gaming'], dtype=object), ' Correlation = ', 0.028978290524003102)
# (array(['sinc_partner', 'gaming'], dtype=object), ' Correlation = ', 0.028430380718652386)
# (array(['samerace', 'fun_want'], dtype=object), ' Correlation = ', 0.028077978554262254)
# (array(['dec', 'samerace'], dtype=object), ' Correlation = ', 0.028036612850034733)
# (array(['hiking', 'date'], dtype=object), ' Correlation = ', 0.027580971683768114)
# (array(['prob', 'amb_want'], dtype=object), ' Correlation = ', 0.027503348963973141)
# (array(['dec', 'reading'], dtype=object), ' Correlation = ', 0.027227562145598894)
# (array(['shar_partner', 'hiking'], dtype=object), ' Correlation = ', 0.027039323053863557)
# (array(['dining', 'age'], dtype=object), ' Correlation = ', 0.026945496814660026)
# (array(['sinc_partner', 'dining'], dtype=object), ' Correlation = ', 0.026840126209334732)
# (array(['shar_want', 'sinc_want'], dtype=object), ' Correlation = ', 0.026804939195736045)
# (array(['intel_self', 'music'], dtype=object), ' Correlation = ', 0.026753865391111006)
# (array(['sinc_want', 'museums'], dtype=object), ' Correlation = ', 0.026627961037350746)
# (array(['date', 'age'], dtype=object), ' Correlation = ', 0.026326530080396281)
# (array(['shar_want', 'music'], dtype=object), ' Correlation = ', 0.026218134728456452)
# (array(['age_partner', 'exercise'], dtype=object), ' Correlation = ', 0.026118140924843398)
# (array(['intel_partner', 'hiking'], dtype=object), ' Correlation = ', 0.025750045713532222)
# (array(['pid', 'fun_want'], dtype=object), ' Correlation = ', 0.025703537731139918)
# (array(['date', 'iid'], dtype=object), ' Correlation = ', 0.025631679166684088)
# (array(['fun_self', 'iid'], dtype=object), ' Correlation = ', 0.025402201233787038)
# (array(['shar_partner', 'gender'], dtype=object), ' Correlation = ', 0.025052524925146882)
# (array(['theater', 'date'], dtype=object), ' Correlation = ', 0.024477839445111779)
# (array(['theater', 'iid'], dtype=object), ' Correlation = ', 0.024421876148853876)
# (array(['attr_partner', 'tvsports'], dtype=object), ' Correlation = ', 0.023652728385162219)
# (array(['reading', 'date'], dtype=object), ' Correlation = ', 0.02361356727593095)
# (array(['int_corr', 'yoga'], dtype=object), ' Correlation = ', 0.023328763628624679)
# (array(['fun_want', 'tvsports'], dtype=object), ' Correlation = ', 0.023298218580625911)
# (array(['age_partner', 'dining'], dtype=object), ' Correlation = ', 0.023292600443311363)
# (array(['fun_want', 'gender'], dtype=object), ' Correlation = ', 0.023164443294864279)
# (array(['movies', 'gaming'], dtype=object), ' Correlation = ', 0.022651880950274962)
# (array(['pid', 'tv'], dtype=object), ' Correlation = ', 0.022303941097495547)
# (array(['intel_partner', 'clubbing'], dtype=object), ' Correlation = ', 0.0222811116577715)
# (array(['amb_partner', 'int_corr'], dtype=object), ' Correlation = ', 0.022130900575354766)
# (array(['age_partner', 'yoga'], dtype=object), ' Correlation = ', 0.021749618288669455)
# (array(['shar_partner', 'movies'], dtype=object), ' Correlation = ', 0.021735019495229192)
# (array(['dec', 'concerts'], dtype=object), ' Correlation = ', 0.021536127208175534)
# (array(['dec', 'hiking'], dtype=object), ' Correlation = ', 0.021533331596920013)
# (array(['int_corr', 'amb_want'], dtype=object), ' Correlation = ', 0.02153138302034846)
# (array(['shar_partner', 'reading'], dtype=object), ' Correlation = ', 0.021430183436274543)
# (array(['sinc_partner', 'exercise'], dtype=object), ' Correlation = ', 0.021313209555441567)
# (array(['attr_want', 'clubbing'], dtype=object), ' Correlation = ', 0.021273071943781498)
# (array(['shar_want', 'museums'], dtype=object), ' Correlation = ', 0.021167400168792289)
# (array(['fun_want', 'yoga'], dtype=object), ' Correlation = ', 0.021124636536981191)
# (array(['fun_self', 'reading'], dtype=object), ' Correlation = ', 0.02109172715807861)
# (array(['yoga', 'age'], dtype=object), ' Correlation = ', 0.02088375365275107)
# (array(['tv', 'museums'], dtype=object), ' Correlation = ', 0.020442345811027517)
# (array(['sinc_self', 'amb_want'], dtype=object), ' Correlation = ', 0.020072287703849077)
# (array(['samerace', 'art'], dtype=object), ' Correlation = ', 0.019642300610620542)
# (array(['amb_partner', 'age_partner'], dtype=object), ' Correlation = ', 0.019465937509997134)
# (array(['amb_want', 'music'], dtype=object), ' Correlation = ', 0.019353908628945524)
# (array(['pid', 'attr_self'], dtype=object), ' Correlation = ', 0.019349820804433315)
# (array(['sinc_partner', 'concerts'], dtype=object), ' Correlation = ', 0.019283837353779254)
# (array(['amb_partner', 'hiking'], dtype=object), ' Correlation = ', 0.019183965460768528)
# (array(['amb_partner', 'sports'], dtype=object), ' Correlation = ', 0.019058838994322851)
# (array(['gaming', 'iid'], dtype=object), ' Correlation = ', 0.018839521762036005)
# (array(['int_corr', 'sinc_self'], dtype=object), ' Correlation = ', 0.01880121707184702)
# (array(['dec', 'art'], dtype=object), ' Correlation = ', 0.018438789895047401)
# (array(['attr_partner', 'int_corr'], dtype=object), ' Correlation = ', 0.017680955696411923)
# (array(['intel_self', 'yoga'], dtype=object), ' Correlation = ', 0.01761441881647063)
# (array(['intel_self', 'attr_want'], dtype=object), ' Correlation = ', 0.017179969989016532)
# (array(['samerace', 'attr_want'], dtype=object), ' Correlation = ', 0.017136441535591917)
# (array(['amb_partner', 'sinc_want'], dtype=object), ' Correlation = ', 0.016113915284663931)
# (array(['int_corr', 'sinc_want'], dtype=object), ' Correlation = ', 0.015935937779852066)
# (array(['concerts', 'date'], dtype=object), ' Correlation = ', 0.015089798960475218)
# (array(['age_partner', 'shopping'], dtype=object), ' Correlation = ', 0.014970233612480569)
# (array(['attr_partner', 'art'], dtype=object), ' Correlation = ', 0.01480330240456372)
# (array(['intel_self', 'art'], dtype=object), ' Correlation = ', 0.014448944432811833)
# (array(['attr_partner', 'attr_want'], dtype=object), ' Correlation = ', 0.014423037801021691)
# (array(['samerace', 'sports'], dtype=object), ' Correlation = ', 0.014215760981297385)
# (array(['attr_partner', 'age'], dtype=object), ' Correlation = ', 0.014044971990169675)
# (array(['samerace', 'int_corr'], dtype=object), ' Correlation = ', 0.014044927751757837)
# (array(['sports', 'iid'], dtype=object), ' Correlation = ', 0.013924890728113114)
# (array(['shar_want', 'movies'], dtype=object), ' Correlation = ', 0.013842307688889072)
# (array(['sinc_partner', 'attr_want'], dtype=object), ' Correlation = ', 0.013602798611728707)
# (array(['attr_partner', 'museums'], dtype=object), ' Correlation = ', 0.013599012920892242)
# (array(['sinc_partner', 'fun_want'], dtype=object), ' Correlation = ', 0.013137552238492171)
# (array(['yoga', 'gaming'], dtype=object), ' Correlation = ', 0.01279396510988659)
# (array(['attr_partner', 'date'], dtype=object), ' Correlation = ', 0.012276394101553333)
# (array(['dec', 'fun_want'], dtype=object), ' Correlation = ', 0.012261238645046623)
# (array(['age_partner', 'movies'], dtype=object), ' Correlation = ', 0.012055405068706037)
# (array(['dec', 'int_corr'], dtype=object), ' Correlation = ', 0.011944423423795066)
# (array(['fun_partner', 'yoga'], dtype=object), ' Correlation = ', 0.011877206694433073)
# (array(['fun_partner', 'samerace'], dtype=object), ' Correlation = ', 0.011720927093993302)
# (array(['yoga', 'iid'], dtype=object), ' Correlation = ', 0.011716578990207097)
# ...
# (array(['samerace', 'date'], dtype=object), ' Correlation = ', -0.037402217039966414)
# (array(['amb_want', 'fun_want'], dtype=object), ' Correlation = ', -0.037881695429908692)
# (array(['fun_partner', 'age_partner'], dtype=object), ' Correlation = ', -0.038596335618967581)
# (array(['dining', 'tvsports'], dtype=object), ' Correlation = ', -0.038710525875194607)
# (array(['fun_want', 'dining'], dtype=object), ' Correlation = ', -0.038780257202840139)
# (array(['fun_partner', 'shar_want'], dtype=object), ' Correlation = ', -0.038812969398687058)
# (array(['intel_self', 'fun_want'], dtype=object), ' Correlation = ', -0.038920098649022947)
# (array(['amb_self', 'fun_want'], dtype=object), ' Correlation = ', -0.039225568325072208)
# (array(['amb_partner', 'age'], dtype=object), ' Correlation = ', -0.03924136868976142)
# (array(['prob', 'movies'], dtype=object), ' Correlation = ', -0.039632043617158427)
# (array(['music', 'age'], dtype=object), ' Correlation = ', -0.040090388699726531)
# (array(['amb_partner', 'iid'], dtype=object), ' Correlation = ', -0.040296522410397558)
# (array(['sinc_partner', 'shar_want'], dtype=object), ' Correlation = ', -0.040406867941005273)
# (array(['samerace', 'music'], dtype=object), ' Correlation = ', -0.041036393915339531)
# (array(['amb_partner', 'shar_want'], dtype=object), ' Correlation = ', -0.04126903854967616)
# (array(['clubbing', 'iid'], dtype=object), ' Correlation = ', -0.041289133705800223)
# (array(['prob', 'sinc_want'], dtype=object), ' Correlation = ', -0.041451539301479698)
# (array(['prob', 'tv'], dtype=object), ' Correlation = ', -0.041494985176902373)
# (array(['intel_partner', 'iid'], dtype=object), ' Correlation = ', -0.041889705744567719)
# (array(['intel_want', 'exercise'], dtype=object), ' Correlation = ', -0.042318570097683687)
# (array(['intel_partner', 'intel_want'], dtype=object), ' Correlation = ', -0.042669619047540741)
# (array(['amb_partner', 'fun_want'], dtype=object), ' Correlation = ', -0.042746583164443318)
# (array(['fun_want', 'art'], dtype=object), ' Correlation = ', -0.042913133013328046)
# (array(['intel_self', 'concerts'], dtype=object), ' Correlation = ', -0.043403064111138916)
# (array(['dec', 'attr_self'], dtype=object), ' Correlation = ', -0.043590872091303114)
# (array(['amb_partner', 'intel_want'], dtype=object), ' Correlation = ', -0.044087025638822108)
# (array(['concerts', 'sports'], dtype=object), ' Correlation = ', -0.044290164665887442)
# (array(['sinc_self', 'intel_want'], dtype=object), ' Correlation = ', -0.045661197030343048)
# (array(['gaming', 'date'], dtype=object), ' Correlation = ', -0.046235557476251007)
# (array(['attr_partner', 'exercise'], dtype=object), ' Correlation = ', -0.04695102993615128)
# (array(['shar_partner', 'iid'], dtype=object), ' Correlation = ', -0.047398997570417753)
# (array(['dec', 'age_partner'], dtype=object), ' Correlation = ', -0.047847911049910388)
# (array(['attr_partner', 'age_partner'], dtype=object), ' Correlation = ', -0.048061390495509247)
# (array(['sinc_partner', 'intel_want'], dtype=object), ' Correlation = ', -0.048095670138353967)
# (array(['samerace', 'sinc_want'], dtype=object), ' Correlation = ', -0.048469583484175176)
# (array(['shar_partner', 'pid'], dtype=object), ' Correlation = ', -0.048533320772548474)
# (array(['samerace', 'gaming'], dtype=object), ' Correlation = ', -0.048889048819348843)
# (array(['samerace', 'yoga'], dtype=object), ' Correlation = ', -0.049679207996879936)
# (array(['yoga', 'date'], dtype=object), ' Correlation = ', -0.050200452942800372)
# (array(['theater', 'gaming'], dtype=object), ' Correlation = ', -0.050228322879569146)
# (array(['shar_partner', 'date'], dtype=object), ' Correlation = ', -0.050374230358884588)
# (array(['shar_partner', 'fun_want'], dtype=object), ' Correlation = ', -0.050647613620725999)
# (array(['intel_partner', 'shar_want'], dtype=object), ' Correlation = ', -0.051858510094207021)
# (array(['attr_want', 'hiking'], dtype=object), ' Correlation = ', -0.052234095724653741)
# (array(['shar_partner', 'intel_want'], dtype=object), ' Correlation = ', -0.053595458690875217)
# (array(['shar_want', 'sports'], dtype=object), ' Correlation = ', -0.054380009625567875)
# (array(['sinc_want', 'sports'], dtype=object), ' Correlation = ', -0.054508087006778214)
# (array(['amb_want', 'intel_want'], dtype=object), ' Correlation = ', -0.058394331249501358)
# (array(['gaming', 'art'], dtype=object), ' Correlation = ', -0.058564973653525587)
# (array(['age_partner', 'gaming'], dtype=object), ' Correlation = ', -0.061103861693718363)
# (array(['concerts', 'exercise'], dtype=object), ' Correlation = ', -0.061367586601453174)
# (array(['fun_partner', 'intel_want'], dtype=object), ' Correlation = ', -0.061707111278218568)
# (array(['sports', 'age'], dtype=object), ' Correlation = ', -0.062180593279206074)
# (array(['samerace', 'dining'], dtype=object), ' Correlation = ', -0.062302674787391869)
# (array(['int_corr', 'clubbing'], dtype=object), ' Correlation = ', -0.062470608753393386)
# (array(['int_corr', 'shopping'], dtype=object), ' Correlation = ', -0.064179137420723897)
# (array(['intel_partner', 'gender'], dtype=object), ' Correlation = ', -0.065090420337798355)
# (array(['amb_self', 'shar_want'], dtype=object), ' Correlation = ', -0.065388267700552907)
# (array(['age_partner', 'attr_want'], dtype=object), ' Correlation = ', -0.065901579145001471)
# (array(['samerace', 'clubbing'], dtype=object), ' Correlation = ', -0.066303041117133921)
# (array(['shar_want', 'clubbing'], dtype=object), ' Correlation = ', -0.066920296437695856)
# (array(['prob', 'intel_want'], dtype=object), ' Correlation = ', -0.066984162362480601)
# (array(['samerace', 'shopping'], dtype=object), ' Correlation = ', -0.067323428727101481)
# (array(['intel_want', 'hiking'], dtype=object), ' Correlation = ', -0.067343035761775971)
# (array(['fun_want', 'reading'], dtype=object), ' Correlation = ', -0.067576711012472243)
# (array(['int_corr', 'attr_want'], dtype=object), ' Correlation = ', -0.068287567453161793)
# (array(['attr_want', 'yoga'], dtype=object), ' Correlation = ', -0.069285138123993673)
# (array(['fun_want', 'theater'], dtype=object), ' Correlation = ', -0.069342811686210398)
# (array(['fun_want', 'museums'], dtype=object), ' Correlation = ', -0.069410552727030936)
# (array(['yoga', 'tvsports'], dtype=object), ' Correlation = ', -0.070910900807559338)
# (array(['clubbing', 'gender'], dtype=object), ' Correlation = ', -0.071204612574755036)
# (array(['intel_want', 'shopping'], dtype=object), ' Correlation = ', -0.071316303229573122)
# (array(['attr_self', 'intel_want'], dtype=object), ' Correlation = ', -0.071483520541173851)
# (array(['gaming', 'museums'], dtype=object), ' Correlation = ', -0.07312039512130307)
# (array(['music', 'gender'], dtype=object), ' Correlation = ', -0.073357038309312159)
# (array(['age_partner', 'gender'], dtype=object), ' Correlation = ', -0.073363574419284913)
# (array(['int_corr', 'sports'], dtype=object), ' Correlation = ', -0.073537993374260494)
# (array(['concerts', 'age'], dtype=object), ' Correlation = ', -0.074091974900846166)
# (array(['hiking', 'gender'], dtype=object), ' Correlation = ', -0.07516839798014037)
# (array(['pid', 'intel_want'], dtype=object), ' Correlation = ', -0.075862457173702671)
# (array(['amb_self', 'age'], dtype=object), ' Correlation = ', -0.07605172580233896)
# (array(['shar_want', 'exercise'], dtype=object), ' Correlation = ', -0.076643578324417747)
# (array(['dec', 'exercise'], dtype=object), ' Correlation = ', -0.077509485464762232)
# (array(['sinc_self', 'fun_want'], dtype=object), ' Correlation = ', -0.078041634283028391)
# (array(['museums', 'tvsports'], dtype=object), ' Correlation = ', -0.078332164036762672)
# (array(['dining', 'sports'], dtype=object), ' Correlation = ', -0.079491836886575226)
# (array(['fun_want', 'concerts'], dtype=object), ' Correlation = ', -0.080072446914577627)
# (array(['reading', 'clubbing'], dtype=object), ' Correlation = ', -0.080487699973858864)
# (array(['attr_self', 'gender'], dtype=object), ' Correlation = ', -0.080572125477735235)
# (array(['sinc_want', 'dining'], dtype=object), ' Correlation = ', -0.081070583880456709)
# (array(['clubbing', 'date'], dtype=object), ' Correlation = ', -0.083578228646059488)
# (array(['intel_want', 'iid'], dtype=object), ' Correlation = ', -0.084533548435814912)
# (array(['intel_want', 'clubbing'], dtype=object), ' Correlation = ', -0.084872442700217168)
# (array(['intel_want', 'tv'], dtype=object), ' Correlation = ', -0.086994439758368222)
# (array(['intel_want', 'gender'], dtype=object), ' Correlation = ', -0.086995508783516029)
# (array(['intel_want', 'gaming'], dtype=object), ' Correlation = ', -0.087790225264243044)
# (array(['shopping', 'date'], dtype=object), ' Correlation = ', -0.087941413411363301)
# (array(['shar_want', 'shopping'], dtype=object), ' Correlation = ', -0.088446410274643991)
# (array(['art', 'tvsports'], dtype=object), ' Correlation = ', -0.08986137808766384)
# (array(['intel_self', 'theater'], dtype=object), ' Correlation = ', -0.091943048894034443)
# (array(['fun_self', 'age'], dtype=object), ' Correlation = ', -0.092596872984607642)
# (array(['amb_want', 'sports'], dtype=object), ' Correlation = ', -0.092792068310868656)
# (array(['amb_self', 'intel_want'], dtype=object), ' Correlation = ', -0.093339275418831316)
# (array(['sinc_self', 'gender'], dtype=object), ' Correlation = ', -0.093584482824797574)
# (array(['fun_want', 'age'], dtype=object), ' Correlation = ', -0.093662510928380877)
# (array(['intel_want', 'music'], dtype=object), ' Correlation = ', -0.094172814122115228)
# (array(['shopping', 'hiking'], dtype=object), ' Correlation = ', -0.094194672341180022)
# (array(['tv', 'sports'], dtype=object), ' Correlation = ', -0.095122107348825133)
# (array(['theater', 'tvsports'], dtype=object), ' Correlation = ', -0.095238908990527532)
# (array(['exercise', 'gender'], dtype=object), ' Correlation = ', -0.095594649586629152)
# (array(['fun_self', 'shar_want'], dtype=object), ' Correlation = ', -0.10114128651793897)
# (array(['clubbing', 'age'], dtype=object), ' Correlation = ', -0.10192782688264002)
# (array(['exercise', 'date'], dtype=object), ' Correlation = ', -0.10215124151884653)
# (array(['intel_want', 'sinc_want'], dtype=object), ' Correlation = ', -0.10274922066606659)
# (array(['attr_want', 'art'], dtype=object), ' Correlation = ', -0.10675069306297999)
# (array(['tv', 'hiking'], dtype=object), ' Correlation = ', -0.1071715820216422)
# (array(['amb_partner', 'gender'], dtype=object), ' Correlation = ', -0.10733016540694768)
# (array(['shopping', 'sports'], dtype=object), ' Correlation = ', -0.10810140402926598)
# (array(['shar_want', 'gender'], dtype=object), ' Correlation = ', -0.10948105963212586)
# (array(['pid', 'amb_want'], dtype=object), ' Correlation = ', -0.10985569717879555)
# (array(['date', 'gender'], dtype=object), ' Correlation = ', -0.11072728471016507)
# (array(['attr_want', 'tv'], dtype=object), ' Correlation = ', -0.11460108004247957)
# (array(['intel_self', 'sinc_want'], dtype=object), ' Correlation = ', -0.11664383083758945)
# (array(['amb_want', 'age'], dtype=object), ' Correlation = ', -0.11672169860125692)
# (array(['dining', 'date'], dtype=object), ' Correlation = ', -0.11723068440596981)
# (array(['sports', 'date'], dtype=object), ' Correlation = ', -0.11740512492079856)
# (array(['sinc_want', 'gender'], dtype=object), ' Correlation = ', -0.11807914981254711)
# (array(['sinc_want', 'exercise'], dtype=object), ' Correlation = ', -0.11826185710016002)
# (array(['reading', 'gender'], dtype=object), ' Correlation = ', -0.12164642438359585)
# (array(['prob', 'date'], dtype=object), ' Correlation = ', -0.12221131702407408)
# (array(['shar_want', 'intel_want'], dtype=object), ' Correlation = ', -0.12566625050269251)
# (array(['concerts', 'gender'], dtype=object), ' Correlation = ', -0.12626932865915258)
# (array(['tvsports', 'age'], dtype=object), ' Correlation = ', -0.13682064928589432)
# (array(['fun_self', 'gender'], dtype=object), ' Correlation = ', -0.13742080887280875)
# (array(['art', 'sports'], dtype=object), ' Correlation = ', -0.1415811777193802)
# (array(['attr_want', 'museums'], dtype=object), ' Correlation = ', -0.14181070409142582)
# (array(['fun_self', 'date'], dtype=object), ' Correlation = ', -0.14259786108770622)
# (array(['museums', 'sports'], dtype=object), ' Correlation = ', -0.14487946857581818)
# (array(['attr_want', 'reading'], dtype=object), ' Correlation = ', -0.14742636766510675)
# (array(['attr_self', 'shar_want'], dtype=object), ' Correlation = ', -0.14868107280932677)
# (array(['amb_want', 'iid'], dtype=object), ' Correlation = ', -0.14994352400653554)
# (array(['reading', 'tvsports'], dtype=object), ' Correlation = ', -0.15076699867307827)
# (array(['fun_self', 'sinc_want'], dtype=object), ' Correlation = ', -0.15395310754569036)
# (array(['movies', 'sports'], dtype=object), ' Correlation = ', -0.1551717321612634)
# (array(['gaming', 'age'], dtype=object), ' Correlation = ', -0.15517388084261038)
# (array(['reading', 'sports'], dtype=object), ' Correlation = ', -0.15629657847005551)
# (array(['fun_want', 'intel_want'], dtype=object), ' Correlation = ', -0.15695509251006992)
# (array(['movies', 'gender'], dtype=object), ' Correlation = ', -0.16030229113508068)
# (array(['int_corr', 'tv'], dtype=object), ' Correlation = ', -0.16132437205698016)
# (array(['shopping', 'age'], dtype=object), ' Correlation = ', -0.16490865256962184)
# (array(['attr_want', 'movies'], dtype=object), ' Correlation = ', -0.16693552424583491)
# (array(['intel_want', 'sports'], dtype=object), ' Correlation = ', -0.16745632445391628)
# (array(['sinc_self', 'attr_want'], dtype=object), ' Correlation = ', -0.16785972230383375)
# (array(['attr_want', 'date'], dtype=object), ' Correlation = ', -0.16957791282167539)
# (array(['amb_self', 'date'], dtype=object), ' Correlation = ', -0.17151168794200061)
# (array(['intel_want', 'tvsports'], dtype=object), ' Correlation = ', -0.17812374515290569)
# (array(['fun_want', 'attr_want'], dtype=object), ' Correlation = ', -0.17895751245500585)
# (array(['intel_self', 'date'], dtype=object), ' Correlation = ', -0.18175588098677206)
# (array(['tv', 'age'], dtype=object), ' Correlation = ', -0.18370211237307987)
# (array(['tv', 'gender'], dtype=object), ' Correlation = ', -0.18905118544149146)
# (array(['fun_want', 'sinc_want'], dtype=object), ' Correlation = ', -0.19324540834631093)
# (array(['attr_want', 'theater'], dtype=object), ' Correlation = ', -0.19887371094842141)
# (array(['attr_self', 'sinc_want'], dtype=object), ' Correlation = ', -0.19891736383954253)
# (array(['shar_want', 'fun_want'], dtype=object), ' Correlation = ', -0.20764746171404455)
# (array(['amb_self', 'sinc_want'], dtype=object), ' Correlation = ', -0.21080979887910459)
# (array(['yoga', 'gender'], dtype=object), ' Correlation = ', -0.21148560990447066)
# (array(['attr_self', 'date'], dtype=object), ' Correlation = ', -0.21343408145446019)
# (array(['fun_self', 'intel_want'], dtype=object), ' Correlation = ', -0.21640625787133375)
# (array(['dining', 'gender'], dtype=object), ' Correlation = ', -0.22390896597911497)
# (array(['museums', 'gender'], dtype=object), ' Correlation = ', -0.22635994673750828)
# (array(['art', 'gender'], dtype=object), ' Correlation = ', -0.23482332822441609)
# (array(['int_corr', 'gaming'], dtype=object), ' Correlation = ', -0.23722191670178064)
# (array(['int_corr', 'tvsports'], dtype=object), ' Correlation = ', -0.24052740545970414)
# (array(['theater', 'sports'], dtype=object), ' Correlation = ', -0.24834953500806051)
# (array(['theater', 'gender'], dtype=object), ' Correlation = ', -0.31867512263800774)
# (array(['intel_want', 'attr_want'], dtype=object), ' Correlation = ', -0.32737884864341277)
# (array(['amb_want', 'gender'], dtype=object), ' Correlation = ', -0.3476830650767897)
# (array(['shopping', 'gender'], dtype=object), ' Correlation = ', -0.3515442438984055)
# (array(['shar_want', 'attr_want'], dtype=object), ' Correlation = ', -0.4133785282997583)
# (array(['sinc_want', 'attr_want'], dtype=object), ' Correlation = ', -0.43307169800449813)
# (array(['amb_want', 'attr_want'], dtype=object), ' Correlation = ', -0.47579153066156643)
# Lowest Correlation Coefficient

# %% [markdown]
# Look at the correlations above. Are there any results that you weren't expecting?

# %% [markdown]
# ### Data Visualization

# %%
from mpl_toolkits.mplot3d import Axes3D

def plotTwoFeatures(f1, f2):
    fig = plt.figure()
    plt.plot(df[f1], df[f2], 'o')
    plt.xlabel(f1)
    plt.ylabel(f2)

# %%
#Hard to see for first two, these are only integers

plotTwoFeatures('art', 'museums')
plotTwoFeatures('intel_partner', 'sinc_partner')
plotTwoFeatures('amb_want', 'attr_want')

# %%
female_df = df.loc[df['gender'] == 0]
male_df = df.loc[df['gender'] == 1]

yes_female_df = female_df.query('dec == 1')
no_female_df = female_df.query('dec == 0')
print('Proportion of acceptance by females is {}'.format(yes_female_df.shape[0]/female_df.shape[0]))

yes_male_df =male_df.query('dec == 1')
no_male_df = male_df.query('dec == 0')
print('Proportion of acceptance by males is {}'.format(yes_male_df.shape[0]/male_df.shape[0]))
# Out:
# Proportion of acceptance by females is 0
# Proportion of acceptance by males is 0

# %%
def plot_feature(feature):
    fig = plt.figure(figsize=(8, 8))
    fig.subplots_adjust(hspace=0.5)
    
    ax = plt.subplot(211)
    ax.set_title('Female')
    ax.set_xlabel(feature)
    x = [no_female_df[feature].values]
    y = [yes_female_df[feature].values]
    plt.hist([x, y], label=['No','Yes'], bins=11)
    ax.legend()
    
    ax = plt.subplot(212)
    ax.set_title('Male')
    ax.set_xlabel(feature)
    x = [no_male_df[feature].values]
    y = [yes_male_df[feature].values]
    plt.hist([x, y], label=['No','Yes'], bins=11)
    ax.legend()
    plt.show()

# %%
#How do the distributions of certain features look like for 'yes' decision and 'no' decision

plot_feature('attr_partner')

# %%
plot_feature('intel_partner')

# %%
plot_feature('shar_partner')

# %% [markdown]
# Any more cool plots you can think of? Fiddle around with the dataset.
